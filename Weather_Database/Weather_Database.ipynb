# %%
# Import dependencies
from citipy import citipy
import numpy as np
import pandas as pd
import requests
import gmaps
from config import weather_api_key, g_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
#         # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    # Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dikson
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | salalah
# Processing Record 4 of Set 1 | upernavik
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | kavaratti
# Processing Record 9 of Set 1 | komsomolskiy
# Processing Record 10 of Set 1 | sur
# Processing Record 11 of Set 1 | hasaki
# Processing Record 12 of Set 1 | mahibadhoo
# Processing Record 13 of Set 1 | likasi
# Processing Record 14 of Set 1 | zhigansk
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | severo-kurilsk
# Processing Record 20 of Set 1 | souillac
# Processing Record 21 of Set 1 | agua verde
# Processing Record 22 of Set 1 | chuy
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | dubovka
# Processing Record 25 of Set 1 | barrow
# Processing Record 26 of Set 1 | saint-augustin
# Processing Record 27 of Set 1 | nikolskoye
# Processing Record 28 of Set 1 | lagoa
# Processing Record 29 of Set 1 | kinlochleven
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 1 | bam
# Processing Record 33 of Set 1 | anar darreh
# City not found. Skipping...
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | sitka
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | kaitangata
# Processing Record 43 of Set 1 | esperance
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | faanui
# Processing Record 46 of Set 1 | sorland
# Processing Record 47 of Set 1 | ipatovo
# Processing Record 48 of Set 1 | mildura
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | la grande
# Processing Record 1 of Set 2 | coos bay
# Processing Record 2 of Set 2 | himora
# City not found. Skipping...
# Processing Record 3 of Set 2 | ostrovnoy
# Processing Record 4 of Set 2 | kumluca
# Processing Record 5 of Set 2 | pemangkat
# Processing Record 6 of Set 2 | toftir
# City not found. Skipping...
# Processing Record 7 of Set 2 | dunedin
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 2 | bredasdorp
# Processing Record 11 of Set 2 | mayo
# Processing Record 12 of Set 2 | bargarh
# Processing Record 13 of Set 2 | jamestown
# Processing Record 14 of Set 2 | arraial do cabo
# Processing Record 15 of Set 2 | malakal
# Processing Record 16 of Set 2 | sao filipe
# Processing Record 17 of Set 2 | bluff
# Processing Record 18 of Set 2 | versalles
# Processing Record 19 of Set 2 | vangaindrano
# Processing Record 20 of Set 2 | norman wells
# Processing Record 21 of Set 2 | busselton
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | terra santa
# Processing Record 24 of Set 2 | fukue
# Processing Record 25 of Set 2 | sars
# Processing Record 26 of Set 2 | palana
# Processing Record 27 of Set 2 | tasiilaq
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | saint-philippe
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | pevek
# Processing Record 32 of Set 2 | zeya
# Processing Record 33 of Set 2 | neiafu
# Processing Record 34 of Set 2 | touros
# Processing Record 35 of Set 2 | ponta do sol
# Processing Record 36 of Set 2 | maumere
# Processing Record 37 of Set 2 | pochutla
# Processing Record 38 of Set 2 | mar del plata
# Processing Record 39 of Set 2 | ganzhou
# Processing Record 40 of Set 2 | fortuna
# Processing Record 41 of Set 2 | codrington
# Processing Record 42 of Set 2 | kysyl-syr
# Processing Record 43 of Set 2 | kurduvadi
# Processing Record 44 of Set 2 | cabo san lucas
# Processing Record 45 of Set 2 | katsuura
# Processing Record 46 of Set 2 | lompoc
# Processing Record 47 of Set 2 | goundam
# Processing Record 48 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 2 | sao tome
# Processing Record 50 of Set 2 | at-bashi
# Processing Record 1 of Set 3 | charters towers
# Processing Record 2 of Set 3 | chinsali
# Processing Record 3 of Set 3 | caledonia
# Processing Record 4 of Set 3 | kathu
# Processing Record 5 of Set 3 | makakilo city
# Processing Record 6 of Set 3 | bambous virieux
# Processing Record 7 of Set 3 | east london
# Processing Record 8 of Set 3 | cherskiy
# Processing Record 9 of Set 3 | kirkuk
# Processing Record 10 of Set 3 | vostok
# Processing Record 11 of Set 3 | chokurdakh
# Processing Record 12 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 13 of Set 3 | lewisporte
# Processing Record 14 of Set 3 | santos dumont
# Processing Record 15 of Set 3 | petukhovo
# Processing Record 16 of Set 3 | pimentel
# Processing Record 17 of Set 3 | sinnamary
# Processing Record 18 of Set 3 | yarovoye
# Processing Record 19 of Set 3 | luderitz
# Processing Record 20 of Set 3 | port hedland
# Processing Record 21 of Set 3 | manta
# Processing Record 22 of Set 3 | mandalgovi
# Processing Record 23 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 3 | chumikan
# Processing Record 25 of Set 3 | clinton
# Processing Record 26 of Set 3 | winchester
# Processing Record 27 of Set 3 | hithadhoo
# Processing Record 28 of Set 3 | yagodnoye
# Processing Record 29 of Set 3 | gandajika
# Processing Record 30 of Set 3 | nome
# Processing Record 31 of Set 3 | pangnirtung
# Processing Record 32 of Set 3 | najran
# Processing Record 33 of Set 3 | ampanihy
# Processing Record 34 of Set 3 | mahebourg
# Processing Record 35 of Set 3 | laguna
# Processing Record 36 of Set 3 | mongagua
# Processing Record 37 of Set 3 | ningan
# City not found. Skipping...
# Processing Record 38 of Set 3 | qaanaaq
# Processing Record 39 of Set 3 | kericho
# Processing Record 40 of Set 3 | saint george
# Processing Record 41 of Set 3 | tuktoyaktuk
# Processing Record 42 of Set 3 | moose factory
# Processing Record 43 of Set 3 | ilulissat
# Processing Record 44 of Set 3 | mazagao
# Processing Record 45 of Set 3 | muros
# Processing Record 46 of Set 3 | gogrial
# Processing Record 47 of Set 3 | georgetown
# Processing Record 48 of Set 3 | hermanus
# Processing Record 49 of Set 3 | fuxin
# Processing Record 50 of Set 3 | yar-sale
# Processing Record 1 of Set 4 | kavieng
# Processing Record 2 of Set 4 | provideniya
# Processing Record 3 of Set 4 | beziers
# Processing Record 4 of Set 4 | nieuw amsterdam
# Processing Record 5 of Set 4 | nsanje
# Processing Record 6 of Set 4 | geraldton
# Processing Record 7 of Set 4 | anamur
# Processing Record 8 of Set 4 | tobias barreto
# Processing Record 9 of Set 4 | zhangye
# Processing Record 10 of Set 4 | oranjemund
# Processing Record 11 of Set 4 | castro
# Processing Record 12 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 4 | aranos
# Processing Record 14 of Set 4 | naze
# Processing Record 15 of Set 4 | jalu
# Processing Record 16 of Set 4 | djibo
# Processing Record 17 of Set 4 | pisco
# Processing Record 18 of Set 4 | lata
# Processing Record 19 of Set 4 | bairiki
# Processing Record 20 of Set 4 | tura
# Processing Record 21 of Set 4 | bengkulu
# Processing Record 22 of Set 4 | longyearbyen
# Processing Record 23 of Set 4 | killybegs
# Processing Record 24 of Set 4 | clyde river
# Processing Record 25 of Set 4 | tual
# Processing Record 26 of Set 4 | mehamn
# Processing Record 27 of Set 4 | mumford
# Processing Record 28 of Set 4 | koungou
# Processing Record 29 of Set 4 | port alfred
# Processing Record 30 of Set 4 | thompson
# Processing Record 31 of Set 4 | poum
# Processing Record 32 of Set 4 | constitucion
# Processing Record 33 of Set 4 | yairipok
# Processing Record 34 of Set 4 | dingle
# Processing Record 35 of Set 4 | tezu
# Processing Record 36 of Set 4 | victoria
# Processing Record 37 of Set 4 | eagle pass
# Processing Record 38 of Set 4 | severnoye
# Processing Record 39 of Set 4 | san patricio
# Processing Record 40 of Set 4 | aloleng
# Processing Record 41 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 42 of Set 4 | leonidovo
# Processing Record 43 of Set 4 | monte alegre
# Processing Record 44 of Set 4 | aklavik
# Processing Record 45 of Set 4 | caravelas
# Processing Record 46 of Set 4 | te anau
# Processing Record 47 of Set 4 | buritama
# Processing Record 48 of Set 4 | hofn
# Processing Record 49 of Set 4 | atar
# Processing Record 50 of Set 4 | elmadag
# Processing Record 1 of Set 5 | smidovich
# Processing Record 2 of Set 5 | eregli
# Processing Record 3 of Set 5 | deloraine
# Processing Record 4 of Set 5 | huzhou
# Processing Record 5 of Set 5 | port hardy
# Processing Record 6 of Set 5 | patan
# Processing Record 7 of Set 5 | namibe
# Processing Record 8 of Set 5 | carnarvon
# Processing Record 9 of Set 5 | zaranj
# Processing Record 10 of Set 5 | cayenne
# Processing Record 11 of Set 5 | airai
# Processing Record 12 of Set 5 | avera
# Processing Record 13 of Set 5 | kodiak
# Processing Record 14 of Set 5 | panshi
# Processing Record 15 of Set 5 | camana
# Processing Record 16 of Set 5 | north bend
# Processing Record 17 of Set 5 | chicama
# Processing Record 18 of Set 5 | hirara
# Processing Record 19 of Set 5 | avallon
# Processing Record 20 of Set 5 | samarai
# Processing Record 21 of Set 5 | carbonia
# Processing Record 22 of Set 5 | qaqortoq
# Processing Record 23 of Set 5 | novo aripuana
# Processing Record 24 of Set 5 | saskylakh
# Processing Record 25 of Set 5 | nuevitas
# Processing Record 26 of Set 5 | ponca city
# Processing Record 27 of Set 5 | cap-aux-meules
# Processing Record 28 of Set 5 | seoul
# Processing Record 29 of Set 5 | barreirinhas
# Processing Record 30 of Set 5 | jasper
# Processing Record 31 of Set 5 | maridi
# Processing Record 32 of Set 5 | port moresby
# Processing Record 33 of Set 5 | inhambane
# Processing Record 34 of Set 5 | mareeba
# Processing Record 35 of Set 5 | grindavik
# Processing Record 36 of Set 5 | alta
# Processing Record 37 of Set 5 | praia
# Processing Record 38 of Set 5 | taoudenni
# Processing Record 39 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 5 | talnakh
# Processing Record 41 of Set 5 | kollumerland
# City not found. Skipping...
# Processing Record 42 of Set 5 | buala
# Processing Record 43 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 5 | eureka
# Processing Record 46 of Set 5 | pekan
# Processing Record 47 of Set 5 | black river
# Processing Record 48 of Set 5 | erzin
# Processing Record 49 of Set 5 | alofi
# Processing Record 50 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 6 | otradnoye
# Processing Record 2 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 3 of Set 6 | pacific grove
# Processing Record 4 of Set 6 | mezen
# Processing Record 5 of Set 6 | livingstonia
# Processing Record 6 of Set 6 | jalpan
# Processing Record 7 of Set 6 | poya
# Processing Record 8 of Set 6 | los llanos de aridane
# Processing Record 9 of Set 6 | nioki
# Processing Record 10 of Set 6 | ullapool
# Processing Record 11 of Set 6 | ust-nera
# Processing Record 12 of Set 6 | marystown
# Processing Record 13 of Set 6 | marsabit
# Processing Record 14 of Set 6 | uddevalla
# Processing Record 15 of Set 6 | anchorage
# Processing Record 16 of Set 6 | rizhao
# Processing Record 17 of Set 6 | hvolsvollur
# Processing Record 18 of Set 6 | faya
# Processing Record 19 of Set 6 | broome
# Processing Record 20 of Set 6 | narsaq
# Processing Record 21 of Set 6 | henties bay
# Processing Record 22 of Set 6 | salinopolis
# Processing Record 23 of Set 6 | manjacaze
# Processing Record 24 of Set 6 | tiksi
# Processing Record 25 of Set 6 | kizukuri
# Processing Record 26 of Set 6 | micheweni
# Processing Record 27 of Set 6 | sao miguel do guama
# Processing Record 28 of Set 6 | quanzhou
# Processing Record 29 of Set 6 | togur
# Processing Record 30 of Set 6 | tautira
# Processing Record 31 of Set 6 | yatou
# Processing Record 32 of Set 6 | stromness
# Processing Record 33 of Set 6 | whyalla
# Processing Record 34 of Set 6 | mayskiy
# Processing Record 35 of Set 6 | point pedro
# Processing Record 36 of Set 6 | baculin
# Processing Record 37 of Set 6 | obo
# Processing Record 38 of Set 6 | gat
# Processing Record 39 of Set 6 | pauini
# Processing Record 40 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 6 | lavrentiya
# Processing Record 42 of Set 6 | palenque
# Processing Record 43 of Set 6 | amga
# Processing Record 44 of Set 6 | ziro
# Processing Record 45 of Set 6 | rocha
# Processing Record 46 of Set 6 | omboue
# Processing Record 47 of Set 6 | chaa-khol
# City not found. Skipping...
# Processing Record 48 of Set 6 | ouallam
# Processing Record 49 of Set 6 | scarborough
# Processing Record 50 of Set 6 | lorengau
# Processing Record 1 of Set 7 | pasewalk
# Processing Record 2 of Set 7 | port said
# Processing Record 3 of Set 7 | zarautz
# Processing Record 4 of Set 7 | prince rupert
# Processing Record 5 of Set 7 | moroni
# Processing Record 6 of Set 7 | ancud
# Processing Record 7 of Set 7 | coahuayana
# Processing Record 8 of Set 7 | kidal
# Processing Record 9 of Set 7 | katy
# Processing Record 10 of Set 7 | huilong
# Processing Record 11 of Set 7 | port lincoln
# Processing Record 12 of Set 7 | cockburn town
# Processing Record 13 of Set 7 | banes
# Processing Record 14 of Set 7 | kadoma
# Processing Record 15 of Set 7 | rock springs
# Processing Record 16 of Set 7 | storforshei
# Processing Record 17 of Set 7 | whitefish
# Processing Record 18 of Set 7 | deputatskiy
# Processing Record 19 of Set 7 | lasa
# Processing Record 20 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 21 of Set 7 | leningradskiy
# Processing Record 22 of Set 7 | nishihara
# Processing Record 23 of Set 7 | cidreira
# Processing Record 24 of Set 7 | gamba
# Processing Record 25 of Set 7 | zaqatala
# Processing Record 26 of Set 7 | canberra
# Processing Record 27 of Set 7 | ca mau
# Processing Record 28 of Set 7 | kirpilskaya
# Processing Record 29 of Set 7 | koslan
# Processing Record 30 of Set 7 | libertador general san martin
# Processing Record 31 of Set 7 | torbay
# Processing Record 32 of Set 7 | udachnyy
# Processing Record 33 of Set 7 | dubti
# Processing Record 34 of Set 7 | seidu
# Processing Record 35 of Set 7 | chhatak
# Processing Record 36 of Set 7 | buchanan
# Processing Record 37 of Set 7 | husavik
# Processing Record 38 of Set 7 | yaan
# Processing Record 39 of Set 7 | mizpe ramon
# City not found. Skipping...
# Processing Record 40 of Set 7 | svetlogorsk
# Processing Record 41 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 7 | sampit
# Processing Record 43 of Set 7 | weligama
# Processing Record 44 of Set 7 | bethel
# Processing Record 45 of Set 7 | sistranda
# Processing Record 46 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 7 | yangambi
# Processing Record 48 of Set 7 | wanning
# Processing Record 49 of Set 7 | pecos
# Processing Record 50 of Set 7 | oktyabrskoye
# Processing Record 1 of Set 8 | olden
# Processing Record 2 of Set 8 | abrau-dyurso
# Processing Record 3 of Set 8 | bismarck
# Processing Record 4 of Set 8 | stara vyzhivka
# Processing Record 5 of Set 8 | tarquinia
# Processing Record 6 of Set 8 | bull savanna
# Processing Record 7 of Set 8 | morant bay
# Processing Record 8 of Set 8 | kirgiz-miyaki
# Processing Record 9 of Set 8 | beloha
# Processing Record 10 of Set 8 | tocopilla
# Processing Record 11 of Set 8 | kisangani
# Processing Record 12 of Set 8 | vaasa
# Processing Record 13 of Set 8 | solhan
# Processing Record 14 of Set 8 | eyl
# Processing Record 15 of Set 8 | padang
# Processing Record 16 of Set 8 | krasnoarmeysk
# Processing Record 17 of Set 8 | asau
# Processing Record 18 of Set 8 | whitehorse
# Processing Record 19 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 8 | flinders
# Processing Record 21 of Set 8 | ponta delgada
# Processing Record 22 of Set 8 | nanortalik
# Processing Record 23 of Set 8 | agadir
# Processing Record 24 of Set 8 | petatlan
# Processing Record 25 of Set 8 | sorong
# Processing Record 26 of Set 8 | cururupu
# Processing Record 27 of Set 8 | raudeberg
# Processing Record 28 of Set 8 | bay roberts
# Processing Record 29 of Set 8 | anadyr
# Processing Record 30 of Set 8 | luau
# Processing Record 31 of Set 8 | tomohon
# Processing Record 32 of Set 8 | viedma
# Processing Record 33 of Set 8 | oksfjord
# Processing Record 34 of Set 8 | rhyl
# Processing Record 35 of Set 8 | fort nelson
# Processing Record 36 of Set 8 | lucapa
# Processing Record 37 of Set 8 | half moon bay
# Processing Record 38 of Set 8 | hambantota
# Processing Record 39 of Set 8 | tuatapere
# Processing Record 40 of Set 8 | auki
# Processing Record 41 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 8 | traverse city
# Processing Record 43 of Set 8 | takoradi
# Processing Record 44 of Set 8 | yulara
# Processing Record 45 of Set 8 | neryungri
# Processing Record 46 of Set 8 | namtsy
# Processing Record 47 of Set 8 | braslav
# City not found. Skipping...
# Processing Record 48 of Set 8 | jinji
# Processing Record 49 of Set 8 | ahipara
# Processing Record 50 of Set 8 | san juan
# Processing Record 1 of Set 9 | sayanskiy
# City not found. Skipping...
# Processing Record 2 of Set 9 | playas
# Processing Record 3 of Set 9 | vila velha
# Processing Record 4 of Set 9 | ilorin
# Processing Record 5 of Set 9 | presidente dutra
# Processing Record 6 of Set 9 | fairbanks
# Processing Record 7 of Set 9 | tessalit
# Processing Record 8 of Set 9 | abong mbang
# Processing Record 9 of Set 9 | miranorte
# City not found. Skipping...
# Processing Record 10 of Set 9 | iqaluit
# Processing Record 11 of Set 9 | gorontalo
# Processing Record 12 of Set 9 | maragogi
# Processing Record 13 of Set 9 | nabire
# Processing Record 14 of Set 9 | itamarandiba
# Processing Record 15 of Set 9 | bilma
# Processing Record 16 of Set 9 | chara
# Processing Record 17 of Set 9 | methven
# Processing Record 18 of Set 9 | kilindoni
# Processing Record 19 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 9 | tucuman
# Processing Record 21 of Set 9 | karlstad
# Processing Record 22 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 9 | ballina
# Processing Record 24 of Set 9 | vao
# Processing Record 25 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 9 | coihaique
# Processing Record 27 of Set 9 | torbat-e jam
# Processing Record 28 of Set 9 | mporokoso
# Processing Record 29 of Set 9 | port keats
# Processing Record 30 of Set 9 | kuryk
# Processing Record 31 of Set 9 | roald
# Processing Record 32 of Set 9 | matelandia
# Processing Record 33 of Set 9 | wasilla
# Processing Record 34 of Set 9 | aquiraz
# Processing Record 35 of Set 9 | ciudad bolivar
# Processing Record 36 of Set 9 | koryazhma
# Processing Record 37 of Set 9 | severo-yeniseyskiy
# Processing Record 38 of Set 9 | lichinga
# Processing Record 39 of Set 9 | lindi
# Processing Record 40 of Set 9 | kirksville
# Processing Record 41 of Set 9 | bow island
# Processing Record 42 of Set 9 | batagay-alyta
# Processing Record 43 of Set 9 | sovetskiy
# Processing Record 44 of Set 9 | tanete
# Processing Record 45 of Set 9 | ketchikan
# Processing Record 46 of Set 9 | kirakira
# Processing Record 47 of Set 9 | tazmalt
# Processing Record 48 of Set 9 | ouegoa
# Processing Record 49 of Set 9 | champerico
# Processing Record 50 of Set 9 | san francisco
# Processing Record 1 of Set 10 | isangel
# Processing Record 2 of Set 10 | santa cruz
# Processing Record 3 of Set 10 | buraydah
# Processing Record 4 of Set 10 | srednekolymsk
# Processing Record 5 of Set 10 | pomabamba
# Processing Record 6 of Set 10 | jiuquan
# Processing Record 7 of Set 10 | benavente
# Processing Record 8 of Set 10 | kytlym
# City not found. Skipping...
# Processing Record 9 of Set 10 | loukhi
# Processing Record 10 of Set 10 | puerto escondido
# Processing Record 11 of Set 10 | jiwani
# Processing Record 12 of Set 10 | wukari
# Processing Record 13 of Set 10 | honiara
# Processing Record 14 of Set 10 | vysokogornyy
# Processing Record 15 of Set 10 | labuhan
# Processing Record 16 of Set 10 | shizuishan
# Processing Record 17 of Set 10 | amarante do maranhao
# Processing Record 18 of Set 10 | cap malheureux
# Processing Record 19 of Set 10 | meulaboh
# Processing Record 20 of Set 10 | kahului
# Processing Record 21 of Set 10 | yantal
# Processing Record 22 of Set 10 | aleksandrov gay
# Processing Record 23 of Set 10 | katherine
# Processing Record 24 of Set 10 | hami
# Processing Record 25 of Set 10 | lazaro cardenas
# Processing Record 26 of Set 10 | fengcheng
# Processing Record 27 of Set 10 | morlaix
# Processing Record 28 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 29 of Set 10 | portland
# Processing Record 30 of Set 10 | san jose
# Processing Record 31 of Set 10 | watertown
# Processing Record 32 of Set 10 | baruun-urt
# Processing Record 33 of Set 10 | porto nacional
# Processing Record 34 of Set 10 | mount gambier
# Processing Record 35 of Set 10 | podgornoye
# Processing Record 36 of Set 10 | ramsar
# Processing Record 37 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 38 of Set 10 | sept-iles
# Processing Record 39 of Set 10 | maxixe
# Processing Record 40 of Set 10 | manadhoo
# Processing Record 41 of Set 10 | deniliquin
# Processing Record 42 of Set 10 | sao miguel
# Processing Record 43 of Set 10 | millau
# Processing Record 44 of Set 10 | tirur
# Processing Record 45 of Set 10 | aksay
# Processing Record 46 of Set 10 | hungund
# Processing Record 47 of Set 10 | suntar
# Processing Record 48 of Set 10 | nichinan
# Processing Record 49 of Set 10 | jacareacanga
# Processing Record 50 of Set 10 | melilla
# Processing Record 1 of Set 11 | bandarbeyla
# Processing Record 2 of Set 11 | harper
# Processing Record 3 of Set 11 | nizhnyaya poyma
# Processing Record 4 of Set 11 | cedar city
# Processing Record 5 of Set 11 | hobyo
# Processing Record 6 of Set 11 | vardo
# Processing Record 7 of Set 11 | bemidji
# Processing Record 8 of Set 11 | zvishavane
# Processing Record 9 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 10 of Set 11 | nova vicosa
# Processing Record 11 of Set 11 | klaksvik
# Processing Record 12 of Set 11 | ulladulla
# Processing Record 13 of Set 11 | katobu
# Processing Record 14 of Set 11 | vila franca do campo
# Processing Record 15 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 11 | plymouth
# Processing Record 17 of Set 11 | canico
# Processing Record 18 of Set 11 | vitim
# Processing Record 19 of Set 11 | karratha
# Processing Record 20 of Set 11 | port blair
# Processing Record 21 of Set 11 | muroto
# Processing Record 22 of Set 11 | baiyin
# Processing Record 23 of Set 11 | kautokeino
# Processing Record 24 of Set 11 | kloulklubed
# Processing Record 25 of Set 11 | vestmannaeyjar
# Processing Record 26 of Set 11 | bud
# Processing Record 27 of Set 11 | gushikawa
# Processing Record 28 of Set 11 | bukachacha
# Processing Record 29 of Set 11 | kushiro
# Processing Record 30 of Set 11 | huaral
# Processing Record 31 of Set 11 | mizdah
# Processing Record 32 of Set 11 | alyangula
# Processing Record 33 of Set 11 | camocim
# Processing Record 34 of Set 11 | fare
# Processing Record 35 of Set 11 | kabarnet
# Processing Record 36 of Set 11 | zaterechnyy
# Processing Record 37 of Set 11 | gambela
# Processing Record 38 of Set 11 | yuanping
# Processing Record 39 of Set 11 | kasra
# City not found. Skipping...
# Processing Record 40 of Set 11 | santa maria
# Processing Record 41 of Set 11 | agartala
# Processing Record 42 of Set 11 | namatanai
# Processing Record 43 of Set 11 | fort-shevchenko
# Processing Record 44 of Set 11 | tsalenjikha
# Processing Record 45 of Set 11 | ternate
# Processing Record 46 of Set 11 | zyryanka
# Processing Record 47 of Set 11 | parabel
# Processing Record 48 of Set 11 | morro bay
# Processing Record 49 of Set 11 | yanaul
# Processing Record 50 of Set 11 | kawasaki
# Processing Record 1 of Set 12 | pedro ii
# Processing Record 2 of Set 12 | saint-francois
# Processing Record 3 of Set 12 | dalbandin
# Processing Record 4 of Set 12 | chateaubelair
# Processing Record 5 of Set 12 | noumea
# Processing Record 6 of Set 12 | chivilcoy
# Processing Record 7 of Set 12 | dabhol
# Processing Record 8 of Set 12 | yerbogachen
# Processing Record 9 of Set 12 | enkoping
# Processing Record 10 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 11 of Set 12 | mirik
# Processing Record 12 of Set 12 | requena
# Processing Record 13 of Set 12 | burkhala
# City not found. Skipping...
# Processing Record 14 of Set 12 | houston
# Processing Record 15 of Set 12 | troitsko-pechorsk
# Processing Record 16 of Set 12 | ozinki
# Processing Record 17 of Set 12 | ladario
# Processing Record 18 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 12 | tsumeb
# Processing Record 20 of Set 12 | denpasar
# Processing Record 21 of Set 12 | la paz
# Processing Record 22 of Set 12 | san quintin
# Processing Record 23 of Set 12 | tomari
# Processing Record 24 of Set 12 | korla
# Processing Record 25 of Set 12 | aksarka
# Processing Record 26 of Set 12 | kruisfontein
# Processing Record 27 of Set 12 | hokitika
# Processing Record 28 of Set 12 | bitkine
# Processing Record 29 of Set 12 | thayetmyo
# Processing Record 30 of Set 12 | annonay
# Processing Record 31 of Set 12 | ende
# Processing Record 32 of Set 12 | tanout
# Processing Record 33 of Set 12 | alugan
# Processing Record 34 of Set 12 | la tuque
# Processing Record 35 of Set 12 | sao gabriel da cachoeira
# Processing Record 36 of Set 12 | caetite
# Processing Record 37 of Set 12 | novosergiyevka
# Processing Record 38 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 39 of Set 12 | buin
# Processing Record 40 of Set 12 | merauke
# Processing Record 41 of Set 12 | beringovskiy
# Processing Record 42 of Set 12 | hopelchen
# Processing Record 43 of Set 12 | pedernales
# Processing Record 44 of Set 12 | itarema
# Processing Record 45 of Set 12 | zaysan
# Processing Record 46 of Set 12 | jiran
# Processing Record 47 of Set 12 | lerwick
# Processing Record 48 of Set 12 | byron bay
# Processing Record 49 of Set 12 | fussen
# Processing Record 50 of Set 12 | port augusta
# Processing Record 1 of Set 13 | bin qirdan
# Processing Record 2 of Set 13 | olafsvik
# Processing Record 3 of Set 13 | businga
# Processing Record 4 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 5 of Set 13 | neuquen
# Processing Record 6 of Set 13 | yegorlykskaya
# Processing Record 7 of Set 13 | college
# Processing Record 8 of Set 13 | singaraja
# Processing Record 9 of Set 13 | svelgen
# Processing Record 10 of Set 13 | awbari
# Processing Record 11 of Set 13 | povenets
# Processing Record 12 of Set 13 | amapa
# Processing Record 13 of Set 13 | hovd
# Processing Record 14 of Set 13 | gurkovo
# Processing Record 15 of Set 13 | vrani
# Processing Record 16 of Set 13 | kungurtug
# Processing Record 17 of Set 13 | southbridge
# Processing Record 18 of Set 13 | coulihaut
# City not found. Skipping...
# Processing Record 19 of Set 13 | quatre cocos
# Processing Record 20 of Set 13 | dubbo
# Processing Record 21 of Set 13 | palmer
# Processing Record 22 of Set 13 | marsaxlokk
# Processing Record 23 of Set 13 | pontes e lacerda
# Processing Record 24 of Set 13 | pangai
# Processing Record 25 of Set 13 | mikhaylov
# Processing Record 26 of Set 13 | providencia
# Processing Record 27 of Set 13 | arman
# Processing Record 28 of Set 13 | camopi
# Processing Record 29 of Set 13 | peniche
# Processing Record 30 of Set 13 | chochola
# Processing Record 31 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 32 of Set 13 | ambunti
# Processing Record 33 of Set 13 | araouane
# Processing Record 34 of Set 13 | la primavera
# Processing Record 35 of Set 13 | bhag
# Processing Record 36 of Set 13 | vila
# Processing Record 37 of Set 13 | alice springs
# Processing Record 38 of Set 13 | kununurra
# Processing Record 39 of Set 13 | san carlos de bariloche
# Processing Record 40 of Set 13 | hohhot
# Processing Record 41 of Set 13 | berlevag
# Processing Record 42 of Set 13 | elk point
# Processing Record 43 of Set 13 | potiskum
# Processing Record 44 of Set 13 | ariquemes
# Processing Record 45 of Set 13 | nanakuli
# Processing Record 46 of Set 13 | saldanha
# Processing Record 47 of Set 13 | boyolangu
# Processing Record 48 of Set 13 | egvekinot
# Processing Record 49 of Set 13 | opuwo
# Processing Record 50 of Set 13 | san cristobal
# Processing Record 1 of Set 14 | malmesbury
# Processing Record 2 of Set 14 | kovdor
# Processing Record 3 of Set 14 | sidi ali
# Processing Record 4 of Set 14 | maniitsoq
# Processing Record 5 of Set 14 | bulgan
# Processing Record 6 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 14 | puerto del rosario
# Processing Record 8 of Set 14 | risor
# Processing Record 9 of Set 14 | necochea
# Processing Record 10 of Set 14 | roma
# Processing Record 11 of Set 14 | vrangel
# Processing Record 12 of Set 14 | manitouwadge
# Processing Record 13 of Set 14 | kobojango
# City not found. Skipping...
# Processing Record 14 of Set 14 | nouadhibou
# Processing Record 15 of Set 14 | gimli
# Processing Record 16 of Set 14 | cazaje
# City not found. Skipping...
# Processing Record 17 of Set 14 | bluefield
# Processing Record 18 of Set 14 | anloga
# Processing Record 19 of Set 14 | preobrazheniye
# Processing Record 20 of Set 14 | gornyy
# Processing Record 21 of Set 14 | waingapu
# Processing Record 22 of Set 14 | turbat
# Processing Record 23 of Set 14 | general pico
# Processing Record 24 of Set 14 | aporawan
# City not found. Skipping...
# Processing Record 25 of Set 14 | lazurne
# Processing Record 26 of Set 14 | kensington
# Processing Record 27 of Set 14 | medea
# Processing Record 28 of Set 14 | puerto madryn
# Processing Record 29 of Set 14 | forio
# Processing Record 30 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 31 of Set 14 | puerto penasco
# Processing Record 32 of Set 14 | sola
# Processing Record 33 of Set 14 | berbera
# Processing Record 34 of Set 14 | dali
# Processing Record 35 of Set 14 | coihueco
# Processing Record 36 of Set 14 | kajaani
# Processing Record 37 of Set 14 | dharchula
# Processing Record 38 of Set 14 | khuzdar
# Processing Record 39 of Set 14 | leshukonskoye
# Processing Record 40 of Set 14 | gazli
# Processing Record 41 of Set 14 | abu kamal
# Processing Record 42 of Set 14 | nadym
# Processing Record 43 of Set 14 | temiscaming
# Processing Record 44 of Set 14 | jiaozuo
# Processing Record 45 of Set 14 | grand gaube
# Processing Record 46 of Set 14 | ucluelet
# Processing Record 47 of Set 14 | luoyang
# Processing Record 48 of Set 14 | gidam
# Processing Record 49 of Set 14 | sao joao da barra
# Processing Record 50 of Set 14 | vanino
# Processing Record 1 of Set 15 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 2 of Set 15 | rawson
# Processing Record 3 of Set 15 | port lavaca
# Processing Record 4 of Set 15 | kieta
# Processing Record 5 of Set 15 | las margaritas
# Processing Record 6 of Set 15 | lakes entrance
# Processing Record 7 of Set 15 | antofagasta
# Processing Record 8 of Set 15 | superior
# Processing Record 9 of Set 15 | vilyuysk
# Processing Record 10 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 15 | mbandaka
# Processing Record 12 of Set 15 | pundaguitan
# Processing Record 13 of Set 15 | kenai
# Processing Record 14 of Set 15 | teya
# Processing Record 15 of Set 15 | vanimo
# Processing Record 16 of Set 15 | caucaia
# Processing Record 17 of Set 15 | vestmanna
# Processing Record 18 of Set 15 | ola
# Processing Record 19 of Set 15 | lemesos
# City not found. Skipping...
# Processing Record 20 of Set 15 | yacuiba
# Processing Record 21 of Set 15 | turiacu
# Processing Record 22 of Set 15 | la ronge
# Processing Record 23 of Set 15 | margate
# Processing Record 24 of Set 15 | homnabad
# Processing Record 25 of Set 15 | arecibo
# Processing Record 26 of Set 15 | macomb
# Processing Record 27 of Set 15 | ushtobe
# Processing Record 28 of Set 15 | tevaitoa
# Processing Record 29 of Set 15 | palkonda
# Processing Record 30 of Set 15 | praia da vitoria
# Processing Record 31 of Set 15 | polovinnoye
# Processing Record 32 of Set 15 | klaeng
# Processing Record 33 of Set 15 | sambava
# Processing Record 34 of Set 15 | anito
# Processing Record 35 of Set 15 | boddam
# Processing Record 36 of Set 15 | mahemdavad
# Processing Record 37 of Set 15 | vyazemskiy
# Processing Record 38 of Set 15 | nantucket
# Processing Record 39 of Set 15 | kadhan
# Processing Record 40 of Set 15 | booue
# Processing Record 41 of Set 15 | karla
# Processing Record 42 of Set 15 | puerto cabezas
# Processing Record 43 of Set 15 | marienburg
# Processing Record 44 of Set 15 | rafai
# Processing Record 45 of Set 15 | liverpool
# Processing Record 46 of Set 15 | umm kaddadah
# Processing Record 47 of Set 15 | kaeo
# Processing Record 48 of Set 15 | visby
# Processing Record 49 of Set 15 | rio grande
# Processing Record 50 of Set 15 | kanniyakumari
# Processing Record 1 of Set 16 | marquette
# Processing Record 2 of Set 16 | mpraeso
# Processing Record 3 of Set 16 | bathsheba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Dikson      RU  73.5069   80.5464     32.27        98         100
# 1         Ushuaia      AR -54.8000  -68.3000     28.06       100          75
# 2         Salalah      OM  17.0151   54.0924     86.09        79          20
# 3       Upernavik      GL  72.7868  -56.1549     31.44        82          84
# 4       Cape Town      ZA -33.9258   18.4232     66.11        61          20
# 5     New Norfolk      AU -42.7826  147.0587     54.91        69          75
# 6  Ribeira Grande      PT  38.5167  -28.7000     64.80        52          40
# 7       Kavaratti      IN  10.5669   72.6420     83.95        75         100
# 8    Komsomolskiy      UZ  40.4272   71.7189     92.12        16          25
# 9             Sur      OM  22.5667   59.5289     97.00        38           0
#
#    Wind Speed Current Description
# 0       10.60     overcast clouds
# 1        5.75       broken clouds
# 2        9.22          few clouds
# 3        1.74       broken clouds
# 4        1.01          few clouds
# 5        1.99       broken clouds
# 6       12.66    scattered clouds
# 7       20.22     overcast clouds
# 8        0.00    scattered clouds
# 9        3.89           clear sky

# %%
# Export to CSV
city_data_df.to_csv('WeatherPy_Database.csv', index=None)
