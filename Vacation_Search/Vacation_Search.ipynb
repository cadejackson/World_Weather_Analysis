# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import os
import numpy as np

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
file_path = os.path.join('..', "Weather_Database/WeatherPy_database.csv")
city_data_df = pd.read_csv(file_path)
city_data_df.head()
# Out:
#         City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0     Dikson      RU  73.5069  80.5464     32.27        98         100
# 1    Ushuaia      AR -54.8000 -68.3000     28.06       100          75
# 2    Salalah      OM  17.0151  54.0924     86.09        79          20
# 3  Upernavik      GL  72.7868 -56.1549     31.44        82          84
# 4  Cape Town      ZA -33.9258  18.4232     66.11        61          20
#
#    Wind Speed Current Description
# 0       10.60     overcast clouds
# 1        5.75       broken clouds
# 2        9.22          few clouds
# 3        1.74       broken clouds
# 4        1.01          few clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 85
# What is the maximum temperature you would like for your trip? 95

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#              City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 2         Salalah      OM  17.0151  54.0924     86.09        79          20
# 8    Komsomolskiy      UZ  40.4272  71.7189     92.12        16          25
# 53        Bargarh      IN  21.3333  83.6167     94.91        31          36
# 64    Terra Santa      BR  -2.1042 -56.4869     86.90        65          33
# 75         Touros      BR  -5.1989 -35.4608     85.10        56           2
# 84      Kurduvadi      IN  18.0833  75.4333     92.03        42          91
# 94          Kathu      TH   7.9178  98.3332     89.62        72          76
# 117     Gandajika      CD  -6.7500  23.9500     90.75        23          96
# 131       Mazagao      BR  -0.1150 -51.2894     86.05        82           8
# 142        Nsanje      MW -16.9200  35.2620     85.37        43          80
#
#      Wind Speed Current Description
# 2          9.22          few clouds
# 8          0.00    scattered clouds
# 53         2.98    scattered clouds
# 64         2.82    scattered clouds
# 75        14.54           clear sky
# 84        11.21     overcast clouds
# 94         7.90       broken clouds
# 117        2.39     overcast clouds
# 131        3.33           clear sky
# 142        5.99       broken clouds

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.isnull().sum()
# Out:
# City                   0
# Country                0
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna()

# %%
clean_df
# Out:
#                      City Country      Lat       Lng  Max Temp  Humidity  \
# 2                 Salalah      OM  17.0151   54.0924     86.09        79
# 8            Komsomolskiy      UZ  40.4272   71.7189     92.12        16
# 53                Bargarh      IN  21.3333   83.6167     94.91        31
# 64            Terra Santa      BR  -2.1042  -56.4869     86.90        65
# 75                 Touros      BR  -5.1989  -35.4608     85.10        56
# 84              Kurduvadi      IN  18.0833   75.4333     92.03        42
# 94                  Kathu      TH   7.9178   98.3332     89.62        72
# 117             Gandajika      CD  -6.7500   23.9500     90.75        23
# 131               Mazagao      BR  -0.1150  -51.2894     86.05        82
# 142                Nsanje      MW -16.9200   35.2620     85.37        43
# 151                  Jalu      LY  29.0331   21.5482     93.99        17
# 178          Monte Alegre      BR  -2.0078  -54.0692     85.10        65
# 208         Novo Aripuana      BR  -5.1206  -60.3797     88.72        43
# 214          Barreirinhas      BR  -2.7469  -42.8264     87.60        58
# 216                Maridi      SS   4.9158   29.4742     88.02        54
# 228           Black River      JM  18.0264  -77.8487     85.98        61
# 247                  Faya      SA  18.3851   42.4509     86.52         9
# 251           Salinopolis      BR  -0.6136  -47.3561     85.06        66
# 256   Sao Miguel Do Guama      BR  -1.6267  -47.4833     87.15        62
# 266                   Obo      CF   5.3998   26.4869     91.94        43
# 267                   Gat      IL  31.6100   34.7642     85.41        45
# 284            Coahuayana      MX  18.7333 -103.6833     85.48        69
# 310                 Seidu      SL   9.0167  -10.6000     85.06        57
# 320              Yangambi      CD   0.8102   24.4336     87.69        48
# 330            Morant Bay      JM  17.8815  -76.4093     85.62        65
# 348              Cururupu      BR  -1.8283  -44.8683     87.67        57
# 358                Lucapa      AO  -8.4192   20.7447     87.91        16
# 373                Ilorin      NG   8.5000    4.5500     88.16        62
# 374      Presidente Dutra      BR  -5.2900  -44.4900     86.61        50
# 399               Aquiraz      BR  -3.9014  -38.3911     88.21        50
# 414            Champerico      GT  14.3000  -91.9167     89.73        76
# 425                Jiwani      PK  25.0500   61.7417     88.97        75
# 431  Amarante Do Maranhao      BR  -5.5667  -46.7422     86.18        48
# 454            Sao Miguel      BR  -5.4667  -35.3667     86.32        58
# 458               Hungund      IN  16.0667   76.0500     90.01        47
# 461          Jacareacanga      BR  -6.2222  -57.7528     88.11        62
# 491                Mizdah      LY  31.4451   12.9801     94.28        17
# 493               Camocim      BR  -2.9022  -40.8411     86.65        58
# 510              Pedro Ii      BR  -4.4247  -41.4586     85.32        43
# 535             Thayetmyo      MM  19.3167   95.1833     88.34        57
# 549               Itarema      BR  -2.9248  -39.9167     86.02        61
# 566                 Amapa      BR   1.0000  -52.0000     85.50        64
# 630               Berbera      SO  10.4396   45.0143     90.46        62
# 645                 Gidam      IN  18.9833   81.4000     87.12        50
# 661               Caucaia      BR  -3.7361  -38.6531     88.07        68
# 665               Turiacu      BR  -1.6633  -45.3717     87.39        58
# 668              Homnabad      IN  17.7667   77.1333     91.65        40
# 669               Arecibo      PR  18.4724  -66.7157     87.19        75
# 673              Palkonda      IN  18.6000   83.7500     88.30        64
# 676                Klaeng      TH  12.7797  101.6483     90.95        90
# 683                Kadhan      PK  24.4810   68.9859     88.07        67
# 686        Puerto Cabezas      NI  14.0351  -83.3888     85.96        70
# 688                 Rafai      CF   4.9500   23.9167     85.82        53
# 697             Bathsheba      BB  13.2167  -59.5167     86.61        51
#
#      Cloudiness  Wind Speed Current Description
# 2            20        9.22          few clouds
# 8            25        0.00    scattered clouds
# 53           36        2.98    scattered clouds
# 64           33        2.82    scattered clouds
# 75            2       14.54           clear sky
# 84           91       11.21     overcast clouds
# 94           76        7.90       broken clouds
# 117          96        2.39     overcast clouds
# 131           8        3.33           clear sky
# 142          80        5.99       broken clouds
# 151           0       14.00           clear sky
# 178          10        3.80           clear sky
# 208           8        3.44           clear sky
# 214           2        5.50           clear sky
# 216         100        4.68     overcast clouds
# 228           3        1.43           clear sky
# 247           1       20.92           clear sky
# 251          30        8.10    scattered clouds
# 256          65        4.07       broken clouds
# 266          44        4.41    scattered clouds
# 267           0       13.87           clear sky
# 284          74        1.81       broken clouds
# 310         100        1.70     overcast clouds
# 320         100        3.31     overcast clouds
# 330           6        8.39          light rain
# 348           1        4.97           clear sky
# 358          80        2.37       broken clouds
# 373          20        6.91          few clouds
# 374          12        4.61          few clouds
# 399          23       12.21          few clouds
# 414          93        6.98     overcast clouds
# 425           0       12.08           clear sky
# 431           6        5.59           clear sky
# 454          10       15.48           clear sky
# 458         100       14.85     overcast clouds
# 461           0        4.61           clear sky
# 491          81       10.29       broken clouds
# 493           6        6.96           clear sky
# 510           4        4.70           clear sky
# 535          33        8.10    scattered clouds
# 549           3       11.95           clear sky
# 566          19        2.80          few clouds
# 630          11        9.93          few clouds
# 645          78        1.72       broken clouds
# 661          40       10.98    scattered clouds
# 665           3        4.85           clear sky
# 668          44        9.10    scattered clouds
# 669          99        1.99     overcast clouds
# 673          59        6.44       broken clouds
# 676          12        4.81          few clouds
# 683           0       20.15           clear sky
# 686          75        4.61       broken clouds
# 688         100        3.62     overcast clouds
# 697          40       13.89    scattered clouds

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#              City Country  Max Temp Current Description      Lat      Lng  \
# 2         Salalah      OM     86.09          few clouds  17.0151  54.0924
# 8    Komsomolskiy      UZ     92.12    scattered clouds  40.4272  71.7189
# 53        Bargarh      IN     94.91    scattered clouds  21.3333  83.6167
# 64    Terra Santa      BR     86.90    scattered clouds  -2.1042 -56.4869
# 75         Touros      BR     85.10           clear sky  -5.1989 -35.4608
# 84      Kurduvadi      IN     92.03     overcast clouds  18.0833  75.4333
# 94          Kathu      TH     89.62       broken clouds   7.9178  98.3332
# 117     Gandajika      CD     90.75     overcast clouds  -6.7500  23.9500
# 131       Mazagao      BR     86.05           clear sky  -0.1150 -51.2894
# 142        Nsanje      MW     85.37       broken clouds -16.9200  35.2620
#
#     Hotel Name
# 2
# 8
# 53
# 64
# 75
# 84
# 94
# 117
# 131
# 142

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add LAt/Long to params
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, 'Hotel Name'] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df['Hotel Name'] = hotel_df['Hotel Name'].replace("", np.nan)
hotel_df.count()
# Out:
# City                   54
# Country                54
# Max Temp               54
# Current Description    54
# Lat                    54
# Lng                    54
# Hotel Name             47
# dtype: int64

# %%
clean_hotel_df = hotel_df.dropna()
clean_hotel_df
# Out:
#                      City Country  Max Temp Current Description      Lat  \
# 2                 Salalah      OM     86.09          few clouds  17.0151
# 8            Komsomolskiy      UZ     92.12    scattered clouds  40.4272
# 53                Bargarh      IN     94.91    scattered clouds  21.3333
# 64            Terra Santa      BR     86.90    scattered clouds  -2.1042
# 75                 Touros      BR     85.10           clear sky  -5.1989
# 84              Kurduvadi      IN     92.03     overcast clouds  18.0833
# 94                  Kathu      TH     89.62       broken clouds   7.9178
# 131               Mazagao      BR     86.05           clear sky  -0.1150
# 142                Nsanje      MW     85.37       broken clouds -16.9200
# 151                  Jalu      LY     93.99           clear sky  29.0331
# 178          Monte Alegre      BR     85.10           clear sky  -2.0078
# 208         Novo Aripuana      BR     88.72           clear sky  -5.1206
# 214          Barreirinhas      BR     87.60           clear sky  -2.7469
# 228           Black River      JM     85.98           clear sky  18.0264
# 247                  Faya      SA     86.52           clear sky  18.3851
# 251           Salinopolis      BR     85.06    scattered clouds  -0.6136
# 256   Sao Miguel Do Guama      BR     87.15       broken clouds  -1.6267
# 267                   Gat      IL     85.41           clear sky  31.6100
# 284            Coahuayana      MX     85.48       broken clouds  18.7333
# 330            Morant Bay      JM     85.62          light rain  17.8815
# 348              Cururupu      BR     87.67           clear sky  -1.8283
# 358                Lucapa      AO     87.91       broken clouds  -8.4192
# 373                Ilorin      NG     88.16          few clouds   8.5000
# 374      Presidente Dutra      BR     86.61          few clouds  -5.2900
# 399               Aquiraz      BR     88.21          few clouds  -3.9014
# 414            Champerico      GT     89.73     overcast clouds  14.3000
# 425                Jiwani      PK     88.97           clear sky  25.0500
# 431  Amarante Do Maranhao      BR     86.18           clear sky  -5.5667
# 454            Sao Miguel      BR     86.32           clear sky  -5.4667
# 458               Hungund      IN     90.01     overcast clouds  16.0667
# 461          Jacareacanga      BR     88.11           clear sky  -6.2222
# 491                Mizdah      LY     94.28       broken clouds  31.4451
# 493               Camocim      BR     86.65           clear sky  -2.9022
# 510              Pedro Ii      BR     85.32           clear sky  -4.4247
# 535             Thayetmyo      MM     88.34    scattered clouds  19.3167
# 549               Itarema      BR     86.02           clear sky  -2.9248
# 630               Berbera      SO     90.46          few clouds  10.4396
# 645                 Gidam      IN     87.12       broken clouds  18.9833
# 661               Caucaia      BR     88.07    scattered clouds  -3.7361
# 665               Turiacu      BR     87.39           clear sky  -1.6633
# 668              Homnabad      IN     91.65    scattered clouds  17.7667
# 669               Arecibo      PR     87.19     overcast clouds  18.4724
# 673              Palkonda      IN     88.30       broken clouds  18.6000
# 676                Klaeng      TH     90.95          few clouds  12.7797
# 683                Kadhan      PK     88.07           clear sky  24.4810
# 686        Puerto Cabezas      NI     85.96       broken clouds  14.0351
# 697             Bathsheba      BB     86.61    scattered clouds  13.2167
#
#           Lng                           Hotel Name
# 2     54.0924           HAMDAN PLAZA HOTEL SALALAH
# 8     71.7189                            Ikathouse
# 53    83.6167                      HOTEL VD PALACE
# 64   -56.4869                          Hotel Sarah
# 75   -35.4608                      INN NEW HORIZON
# 84    75.4333           Trimurti Hotel and Lodging
# 94    98.3332                Novotel Phuket Resort
# 131  -51.2894                Recanto dos Ferreiras
# 142   35.2620               Nsanje Discovery Lodge
# 151   21.5482                        صاحبة الفخامة
# 178  -54.0692                       Hotel Shekinah
# 208  -60.3797                       Hotel Ezequiel
# 214  -42.8264          Gran Lençóis Flat Residence
# 228  -77.8487             Idlers' Rest Beach Hotel
# 247   42.4509                        مقبرة ال مجمل
# 251  -47.3561   Salinas Park Resort Maçarico AP101
# 256  -47.4833                      Hotel Rio Guamá
# 267   34.7642                             OlusHome
# 284 -103.6833    El rranchito michuacan de ocampos
# 330  -76.4093        Whispering Bamboo Cove Resort
# 348  -44.8683                   POUSADA TRAVÉS'CIA
# 358   20.7447        Residência Ulisses Dos Santos
# 373    4.5500                    Ayala Suite Annex
# 374  -44.4900                     Pousada Planalto
# 399  -38.3911                Pousada Rua Camurupim
# 414  -91.9167    Hotel y restaurante "El Diamante"
# 425   61.7417           Al Mumtaz Transport Jiwani
# 431  -46.7422                     Hotéis Caçulinha
# 454  -35.3667  CEJ - Centro Escoteiro da Juventude
# 458   76.0500                    B S Hosur Rrt PDO
# 461  -57.7528                         Casa do Ian😎
# 491   12.9801                  محمدالمبروك الاريقط
# 493  -40.8411                   Hotel Ilha do Amor
# 510  -41.4586                 Opala Hotel Pedro II
# 535   95.1833         Htarwaya Thitsar Guest House
# 549  -39.9167   Sea Lounge! Bar, Club & Restaurant
# 630   45.0143            IBCO REAL ESTATE PROPERTY
# 645   81.4000        Dhanshree Lodge And DormItory
# 661  -38.6531  M.O.S. Logística - Filial Fortaleza
# 665  -45.3717                     Pousada Maranata
# 668   77.1333                       Marthand Vilas
# 669  -66.7157                  Atlantic Sand Oasis
# 673   83.7500            Ayyappa Shankar residency
# 676  101.6483               Damrongcheep in Resort
# 683   68.9859              ڳوٺ چوڌري جلال الدين جٽ
# 686  -83.3888                        Cabaña Caribe
# 697  -59.5167                       Atlantis Hotel

# %%
# 8a. Create the output File (CSV)
output_data_file = 'WeatherPy_vacation.csv'

# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
locations = clean_hotel_df[["Lat", "Lng"]]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
